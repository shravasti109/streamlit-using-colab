# %%
# !pip install -q streamlit  #installing streamlit

# %% [markdown]
# ## to create the app which write hello world

# %%
# %%writefile ap.py
import streamlit as st
st.write("hello world")
# Out:
# Writing ap.py

# %%
# !npm install localtunnel # to laugh the local tunnel
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇
# added 22 packages in 2s
# ⠇
# ⠇3 packages are looking for funding
# ⠇  run `npm fund` for details
# ⠇

# %%
# !streamlit run ap.py &>/content/logs.txt & # con

# %%
# !npx localtunnel --port 8501
# Out:
# ⠙your url is: https://cyan-nights-grab.loca.lt
# ^C
